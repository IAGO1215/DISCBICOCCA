# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 
cwd = "..\\..\\"
cwd_Images_Raw = cwd + "\\Sentinel-2 Images Raw"
cwd_Images_Processed = cwd + "\\Sentinel-2 Images Processed"

# %%
df = pd.read_excel(cwd + "\\Results\\Variogram - Fitting Results.xlsx")
df.head()
# Out:
#    Number                  Site   Latitude  Longitude    Main Ecosystem  \
# 0       1                  ATGE  52.466778  12.959778               NaN
# 1       2      ATLAS-Mohammed V  33.406152  -5.103319               NaN
# 2       3  ATLAS-Mohammed V New  33.404814  -5.101614               NaN
# 3       4                AT-Mmg  47.316700  10.970300  Evergreen Forest
# 4       5                  BASP  39.049139  -2.075917               NaN
#
#   FLOX Activity Reference Network Variogram Fitting Strange     CV 30  ...  \
# 0           NaN          HYPERNET              Good     NaN  0.256794  ...
# 1           NaN             Other               Bad     NaN  0.055660  ...
# 2           NaN             Other               Bad     NaN  0.123388  ...
# 3           Yes              FLOX              Good     NaN  0.033692  ...
# 4           NaN          HYPERNET              Good     Yes  0.011019  ...
#
#      CV 100    Sill 100    CV 300    Sill 300    CV 600    Sill 600    CV 900  \
# 0  0.478179  267.887789  0.428943  449.836840  0.505233  453.765630  0.502820
# 1  0.170407   18.800881  0.236488   39.292309  0.368487   89.614443  0.461659
# 2  0.211488   45.697188  0.245076   71.057738  0.242688   69.552466  0.314551
# 3  0.059300    3.316349  0.056158    3.442307  0.058228    3.904039  0.065007
# 4  0.050378    0.280141  0.208518    5.202114  0.495998   42.031719  0.550165
#
#      Sill 900  Homo Test 600 Homo Test 900
# 0  438.814722            NaN           NaN
# 1  131.031057            NaN           NaN
# 2   99.274666            NaN           NaN
# 3    5.146960            Yes           Yes
# 4   47.130686            NaN           NaN
#
# [5 rows x 21 columns]

# %%
df_GoodFit = df[df['Variogram Fitting'] == 'Good']

# %%
plt.figure(figsize=(6,6))
plt.title("30m x 30m ROI All Sites")
sns.scatterplot(data=df, x="Sill 30", y="CV 30")
# Out:
# <Axes: title={'center': '30m x 30m ROI All Sites'}, xlabel='Sill 30', ylabel='CV 30'>

# %%
plt.figure(figsize=(6,6))
plt.title("30m x 30m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 30", y="CV 30")
# Out:
# <Axes: title={'center': '30m x 30m ROI All Sites with Good Variogram Fitting'}, xlabel='Sill 30', ylabel='CV 30'>

# %%
plt.figure(figsize=(6,6))
plt.title("100m x 100m ROI All Sites")
sns.scatterplot(data=df, x="Sill 100", y="CV 100")
# Out:
# <Axes: title={'center': '100m x 100m ROI All Sites'}, xlabel='Sill 100', ylabel='CV 100'>

# %%
plt.figure(figsize=(6,6))
plt.title("100m x 100m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 100", y="CV 100")
# Out:
# <Axes: title={'center': '100m x 100m ROI All Sites with Good Variogram Fitting'}, xlabel='Sill 100', ylabel='CV 100'>

# %%
plt.figure(figsize=(6,6))
plt.title("300m x 300m ROI All Sites")
sns.scatterplot(data=df, x="Sill 300", y="CV 300")
# Out:
# <Axes: title={'center': '300m x 300m ROI All Sites'}, xlabel='Sill 300', ylabel='CV 300'>

# %%
plt.figure(figsize=(6,6))
plt.title("300m x 300m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 300", y="CV 300")
# Out:
# <Axes: title={'center': '300m x 300m ROI All Sites with Good Variogram Fitting'}, xlabel='Sill 300', ylabel='CV 300'>

# %%
plt.figure(figsize=(6,6))
plt.title("600m x 600m ROI All Sites")
sns.scatterplot(data=df, x="Sill 600", y="CV 600")
# Out:
# <Axes: title={'center': '600m x 600m ROI All Sites'}, xlabel='Sill 600', ylabel='CV 600'>

# %%
plt.figure(figsize=(6,6))
plt.title("600m x 600m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 600", y="CV 600")
# Out:
# <Axes: title={'center': '600m x 600m ROI All Sites with Good Variogram Fitting'}, xlabel='Sill 600', ylabel='CV 600'>

# %%
plt.figure(figsize=(6,6))
plt.title("900m x 900m ROI All Sites")
sns.scatterplot(data=df, x="Sill 900", y="CV 900")
# Out:
# <Axes: title={'center': '900m x 900m ROI All Sites'}, xlabel='Sill 900', ylabel='CV 900'>

# %%
plt.figure(figsize=(6,6))
plt.title("900m x 900m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 900", y="CV 900")
# Out:
# <Axes: title={'center': '900m x 900m ROI All Sites with Good Variogram Fitting'}, xlabel='Sill 900', ylabel='CV 900'>
