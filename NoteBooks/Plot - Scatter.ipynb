# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 
cwd = "..\\..\\"
cwd_Images_Raw = cwd + "\\Sentinel-2 Images Raw"
cwd_Images_Processed = cwd + "\\Sentinel-2 Images Processed"

# %%
df = pd.read_excel(cwd + "\\Results\\Variogram - Fitting Results.xlsx")
df.head()
# Out:
#    Number         Site   Latitude  Longitude    Main Ecosystem FLOX Activity  \
# 0      96       US-LIN  41.179700 -96.440390              Crop           Yes
# 1      48         GHNA -23.601530  15.125890               NaN           NaN
# 2       4       AT-Mmg  47.316700  10.970300  Evergreen Forest           Yes
# 3      99  US-SERC New  38.891407 -76.561638  Deciduous Forest      Possible
# 4      98      US-SERC  38.890130 -76.560000  Deciduous Forest      Possible
#
#   Reference Network Variogram Fitting Strange     CV 30  ...    CV 100  \
# 0              FLOX               Bad     NaN  0.008956  ...  0.019019
# 1          HYPERNET               Bad     NaN  0.056635  ...  0.047539
# 2              FLOX              Good     NaN  0.033692  ...  0.059300
# 3              FLOX               Bad     NaN  0.019452  ...  0.032547
# 4              FLOX               Bad     NaN  0.036599  ...  0.052084
#
# ...

# %%
df_GoodFit = df[df['Variogram Fitting'] == 'Good']

# %%
fig, ax = plt.subplots(figsize = (6,6))
plt.title("30m x 30m ROI All Sites")
sns.scatterplot(data=df, x="Sill 30", y="CV 30")
plt.axhline(y=0.1, color='r', linestyle='-')
plt.axvline(x=8, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [8], labels=list(plt.xticks()[1]) + ['8'])
plt.xlim(-10)
# plt.yticks(list(plt.yticks()[0]) + [0.1])
# plt.ylim(-0.01)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[3].set_color('red')

# %%
fig, ax = plt.subplots(figsize = (6,6))
plt.title("30m x 30m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 30", y="CV 30")
plt.axhline(y=0.1, color='r', linestyle='-')
plt.axvline(x=8, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [8], labels=list(plt.xticks()[1]) + ['8'])
plt.xlim(-10)
# plt.yticks(list(plt.yticks()[0]) + [0.1])
# plt.ylim(-0.01)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[3].set_color('red')

# %%
plt.figure(figsize=(6,6))
plt.title("100m x 100m ROI All Sites")
sns.scatterplot(data=df, x="Sill 100", y="CV 100")
# Out:
# <Axes: title={'center': '100m x 100m ROI All Sites'}, xlabel='Sill 100', ylabel='CV 100'>

# %%
plt.figure(figsize=(6,6))
plt.title("100m x 100m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 100", y="CV 100")
# Out:
# <Axes: title={'center': '100m x 100m ROI All Sites with Good Variogram Fitting'}, xlabel='Sill 100', ylabel='CV 100'>

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.title("300m x 300m ROI All Sites")
sns.scatterplot(data=df, x="Sill 300", y="CV 300")
plt.axhline(y=0.2, color='r', linestyle='-')
plt.axvline(x=60, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [60], labels=list(plt.xticks()[1]) + ['60'])
plt.xlim(-100)
# plt.yticks(list(plt.yticks()[0]) + [0.1])
# plt.ylim(-0.01)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[2].set_color('red')

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.title("300m x 300m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 300", y="CV 300")
plt.axhline(y=0.2, color='r', linestyle='-')
plt.axvline(x=60, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [60], labels=list(plt.xticks()[1]) + ['60'])
plt.xlim(-100)
# plt.yticks(list(plt.yticks()[0]) + [0.1])
# plt.ylim(-0.01)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[2].set_color('red')

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.title("600m x 600m ROI All Sites")
sns.scatterplot(data=df, x="Sill 600", y="CV 600")
plt.axhline(y=0.25, color='r', linestyle='-')
plt.axvline(x=80, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [80], labels=list(plt.xticks()[1]) + ['80'])
plt.xlim(-100)
plt.yticks(list(plt.yticks()[0]) + [0.25], labels=list(plt.yticks()[1]) + ['0.25'])
plt.ylim(-0.02)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[-1].set_color('red')

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.title("600m x 600m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 600", y="CV 600")
plt.axhline(y=0.25, color='r', linestyle='-')
plt.axvline(x=80, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [80], labels=list(plt.xticks()[1]) + ['80'])
plt.xlim(-100)
plt.yticks(list(plt.yticks()[0]) + [0.25], labels=list(plt.yticks()[1]) + ['0.25'])
plt.ylim(-0.02)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[-1].set_color('red')

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.title("900m x 900m ROI All Sites")
sns.scatterplot(data=df, x="Sill 900", y="CV 900")
plt.axhline(y=0.25, color='r', linestyle='-')
plt.axvline(x=110, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [110], labels=list(plt.xticks()[1]) + ['110'])
plt.xlim(-100)
plt.yticks(list(plt.yticks()[0]) + [0.25], labels=list(plt.yticks()[1]) + ['0.25'])
plt.ylim(-0.02)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[-1].set_color('red')

# %%
fig, ax = plt.subplots(figsize=(6,6))
plt.title("900m x 900m ROI All Sites with Good Variogram Fitting")
sns.scatterplot(data=df_GoodFit, x="Sill 900", y="CV 900")
plt.axhline(y=0.25, color='r', linestyle='-')
plt.axvline(x=110, color='r', linestyle='-')
plt.xticks(list(plt.xticks()[0]) + [110], labels=list(plt.xticks()[1]) + ['110'])
plt.xlim(-100)
plt.yticks(list(plt.yticks()[0]) + [0.25], labels=list(plt.yticks()[1]) + ['0.25'])
plt.ylim(-0.02)
ax.xaxis.get_ticklabels()[-1].set_color('red')
ax.yaxis.get_ticklabels()[-1].set_color('red')
