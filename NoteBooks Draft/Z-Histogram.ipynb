# %%
import os
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
cwd = "c:\\Users\\m1865\\Desktop\\DISC"
cwd_Images_Raw = cwd + "\\Sentinel-2 Images Raw"
cwd_Images_Processed = cwd + "\\Sentinel-2 Images Processed"

# %%
pd_Variogram = pd.read_csv(cwd + "\\Result - Variogram.csv")
pd_Variogram.head()
# Out:
#    Site  Distance        STD        CV       Range        Sill        Nugget
# 0  ATGE        30  10.292980  0.256794   20.000000   71.762211  3.570080e+01
# 1  ATGE       100  15.866641  0.478179   70.000000  267.887789  5.104219e-14
# 2  ATGE       300  20.748732  0.428943  104.664412  449.836840  6.333086e+01
# 3  ATGE       900  20.035755  0.502820  345.097181  438.814722  1.064037e+02
# 4  ATGE      1200  19.909969  0.527853  327.228777  419.066655  8.059260e+01

# %%
pd_Roman = pd.read_csv(cwd + "\\Result - Roman.csv")
pd_Roman.head()
# Out:
#    Site  Internal Distance  External Distance       Rcv       Rse       Rst  \
# 0  ATGE                 30                100  0.862114  0.784802  0.990000
# 1  ATGE                 30                300  0.670379  0.788821  0.694206
# 2  ATGE                100                300 -0.102966  0.923035 -0.148640
# 3  ATGE                300                900  0.172231  0.954540 -0.119004
# 4  ATGE                300               1200  0.230590  0.954330 -0.075508
#
#         Rsv  RAW Score  ST Score
# 0  5.965000   0.579970  0.294941
# 1  7.947945   0.745846  0.256871
# 2  0.284701   4.855959  0.907602
# 3  1.906935   2.903070  0.592676
# 4  1.938959   2.168347  0.587308

# %%
pd_Roman.describe()
# Out:
#        Internal Distance  External Distance         Rcv         Rse  \
# count         479.000000         479.000000  479.000000  479.000000
# mean          159.415449         562.004175    1.297177    0.882897
# std           124.766194         407.534879    2.870064    0.081308
# min            30.000000         100.000000   -0.675273    0.755121
# 25%            30.000000         300.000000    0.119270    0.789969
# 50%           100.000000         300.000000    0.509838    0.910760
# 75%           300.000000         900.000000    1.223848    0.961966
# max           300.000000        1200.000000   24.093581    0.977386
#
#               Rst         Rsv   RAW Score    ST Score
# count  479.000000  479.000000  479.000000  479.000000
# mean     0.275855    4.273860    3.644766    0.494056
# std      0.570103    4.903615   13.321130    0.255179
# min     -0.813436   -0.403160    0.020752    0.063355
# 25%     -0.117139    0.887149    0.408548    0.296527
# 50%      0.014772    2.890900    0.976177    0.429207
# 75%      0.878192    5.796172    2.486835    0.684614
# max      4.931382   29.887577  221.760733    1.137635

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of all the distance")
counts, edges, bars = plt.hist(pd_Variogram["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '261'),
#  Text(0, 0, '82'),
#  Text(0, 0, '34'),
#  Text(0, 0, '23'),
#  Text(0, 0, '5'),
#  Text(0, 0, '8'),
#  Text(0, 0, '12'),
#  Text(0, 0, '10'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '1'),
#  Text(0, 0, '4'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 30m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==30]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '25'),
#  Text(0, 0, '12'),
#  Text(0, 0, '10'),
#  Text(0, 0, '12'),
#  Text(0, 0, '3'),
#  Text(0, 0, '5'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance']==30]["Sill"].describe()
# Out:
# count     91.000000
# mean      19.535931
# std       31.244366
# min        0.013728
# 25%        2.521746
# 50%        7.475044
# 75%       16.977178
# max      136.224373
# Name: Sill, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 300m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==300]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '36'),
#  Text(0, 0, '20'),
#  Text(0, 0, '8'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance']==300].describe()
# Out:
#        Distance        STD         CV       Range         Sill        Nugget
# count      91.0  91.000000  91.000000   91.000000    91.000000  9.100000e+01
# mean      300.0   9.918649   0.260920  156.275706   176.213581  1.303411e+01
# std         0.0   8.026690   0.236786   57.521256   327.294005  2.009267e+01
# min       300.0   0.300380   0.045821   37.605226     0.090163  4.633943e-19
# 25%       300.0   4.660064   0.110689  109.245694    21.270344  1.522400e-12
# 50%       300.0   7.369640   0.188784  167.987441    52.807828  3.176279e+00
# 75%       300.0  11.826002   0.285653  210.000000   147.245319  1.802954e+01
# max       300.0  40.138760   1.398979  210.000000  2016.824986  9.687454e+01

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '28'),
#  Text(0, 0, '22'),
#  Text(0, 0, '17'),
#  Text(0, 0, '7'),
#  Text(0, 0, '5'),
#  Text(0, 0, '7'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["Sill"].describe()
# Out:
# count     115.000000
# mean      301.087266
# std       434.115136
# min         0.150287
# 25%        51.699004
# 50%       107.090440
# 75%       317.455169
# max      2445.577708
# Name: Sill, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin(["600m","900m"])]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0')]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of all the distance")
counts, edges, bars = plt.hist(pd_Variogram["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '19'),
#  Text(0, 0, '50'),
#  Text(0, 0, '48'),
#  Text(0, 0, '55'),
#  Text(0, 0, '38'),
#  Text(0, 0, '28'),
#  Text(0, 0, '37'),
#  Text(0, 0, '34'),
#  Text(0, 0, '41'),
#  Text(0, 0, '15'),
#  Text(0, 0, '7'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '6'),
#  Text(0, 0, '10'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '5'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 30m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==30]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '5'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '5'),
#  Text(0, 0, '8'),
#  Text(0, 0, '7'),
#  Text(0, 0, '7'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '7'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance']==30]["CV"].describe()
# Out:
# count    91.000000
# mean      0.104377
# std       0.079959
# min       0.008956
# 25%       0.048581
# 50%       0.081562
# 75%       0.135323
# max       0.413030
# Name: CV, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("CVs of 300m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==300]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '6'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '9'),
#  Text(0, 0, '4'),
#  Text(0, 0, '7'),
#  Text(0, 0, '7'),
#  Text(0, 0, '9'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance']==300]["CV"].describe()
# Out:
# count    91.000000
# mean      0.260920
# std       0.236786
# min       0.045821
# 25%       0.110689
# 50%       0.188784
# 75%       0.285653
# max       1.398979
# Name: CV, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '7'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5'),
#  Text(0, 0, '1'),
#  Text(0, 0, '5'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["CV"].describe()
# Out:
# count    115.000000
# mean       0.331851
# std        0.239880
# min        0.048321
# 25%        0.173625
# 50%        0.251612
# 75%        0.429050
# max        1.278019
# Name: CV, dtype: float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
