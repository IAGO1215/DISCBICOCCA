# %%
import os
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
cwd = "c:\\Users\\m1865\\Desktop\\DISC"
cwd_Images_Raw = cwd + "\\Sentinel-2 Images Raw"
cwd_Images_Processed = cwd + "\\Sentinel-2 Images Processed"

# %%
pd_Variogram = pd.read_csv(cwd + "\\Result - Variogram.csv")
pd_Variogram.head()
# Out:
#    Site Distance       Range        Sill        Nugget        STD        CV
# 0  ATGE      30m   20.000000   99.392275  3.570080e+01  10.292980  0.256794
# 1  ATGE     100m   70.000000  267.887789  4.884311e-14  15.866641  0.478179
# 2  ATGE     300m  104.664413  449.836840  6.333086e+01  20.748732  0.428943
# 3  ATGE     900m  345.097180  438.814722  1.064037e+02  20.035755  0.502820
# 4  ATGE    1200m  327.228777  419.066655  8.059260e+01  19.909969  0.527853

# %%
pd_Roman = pd.read_csv(cwd + "\\Result - Roman.csv")
pd_Roman.head()
# Out:
#    Site Internal Distance External Distance       Rcv       Rse       Rst  \
# 0  ATGE               30m              100m  0.862114  0.784802  0.990000
# 1  ATGE               30m              300m  0.670379  0.788821  0.716754
# 2  ATGE              100m              300m -0.102966  0.923035 -0.137310
# 3  ATGE              300m              900m  0.172231  0.954540 -0.136330
# 4  ATGE              300m             1200m  0.230590  0.954330 -0.068328
#
#          Rsv  RAW Score  ST Score
# 0   8.646682   0.579970  0.233405
# 1  11.393105   0.745846  0.198063
# 2   0.284701   4.855959  0.910724
# 3   1.906935   2.903070  0.590654
# 4   1.938959   2.168347  0.588135

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of all the distance")
counts, edges, bars = plt.hist(pd_Variogram["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '244'),
#  Text(0, 0, '69'),
#  Text(0, 0, '31'),
#  Text(0, 0, '18'),
#  Text(0, 0, '5'),
#  Text(0, 0, '8'),
#  Text(0, 0, '11'),
#  Text(0, 0, '10'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 30m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']=='30m']["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '18'),
#  Text(0, 0, '12'),
#  Text(0, 0, '10'),
#  Text(0, 0, '2'),
#  Text(0, 0, '5'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 300m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']=='300m']["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '34'),
#  Text(0, 0, '16'),
#  Text(0, 0, '8'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin(["600m","900m"])]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '27'),
#  Text(0, 0, '17'),
#  Text(0, 0, '15'),
#  Text(0, 0, '6'),
#  Text(0, 0, '4'),
#  Text(0, 0, '6'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin(["600m","900m"])]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
#                  Site Distance       Range        Sill      Nugget        STD  \
# 3                ATGE     900m  345.097180  438.814722  106.403714  20.035755
# 8    ATLAS-Mohammed V     600m  420.000000   69.804207   26.207774   7.898373
# 9    ATLAS-Mohammed V     900m  630.000000  131.031061    1.541876  11.160982
# 14         AU-MIEMING     900m  630.000000    5.146960    2.030744   2.187106
# 19               BASP     900m  179.047733   47.130686    1.619532   7.137173
# ..                ...      ...         ...         ...         ...        ...
# 424           US-SERC     600m  393.008602   45.531968   15.746688   6.464112
# 425           US-SERC     900m  630.000000  156.993384   57.524923  11.972300
# 430         Utqiagvik     600m  216.915901   13.423323    1.576556   3.581424
# 431         Utqiagvik     900m  578.110852   22.842020    9.835298   4.768883
# 436              WWUK     900m  630.000000  186.540288   90.044759  13.682177
#
#            CV
# 3    0.502820
# 8    0.242353
# 9    0.461659
# 14   0.065007
# 19   0.550165
# ..        ...
# 424  0.077073
# 425  0.151240
# 430  0.188897
# 431  0.251612
# 436  0.156395
#
# [102 rows x 7 columns]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of all the distance")
counts, edges, bars = plt.hist(pd_Variogram["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '16'),
#  Text(0, 0, '47'),
#  Text(0, 0, '45'),
#  Text(0, 0, '51'),
#  Text(0, 0, '34'),
#  Text(0, 0, '27'),
#  Text(0, 0, '33'),
#  Text(0, 0, '31'),
#  Text(0, 0, '39'),
#  Text(0, 0, '12'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '11'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '6'),
#  Text(0, 0, '10'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '4'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 30m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']=='30m']["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '4'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '5'),
#  Text(0, 0, '7'),
#  Text(0, 0, '7'),
#  Text(0, 0, '7'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("CVs of 300m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']=='300m']["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '5'),
#  Text(0, 0, '11'),
#  Text(0, 0, '10'),
#  Text(0, 0, '8'),
#  Text(0, 0, '4'),
#  Text(0, 0, '6'),
#  Text(0, 0, '6'),
#  Text(0, 0, '9'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin(["600m","900m"])]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '5'),
#  Text(0, 0, '9'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '7'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '5'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]
