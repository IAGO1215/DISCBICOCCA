# %%
import os
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
cwd = "c:\\Users\\m1865\\Desktop\\DISC"
cwd_Images_Raw = cwd + "\\Sentinel-2 Images Raw"
cwd_Images_Processed = cwd + "\\Sentinel-2 Images Processed"

# %%
pd_Variogram = pd.read_csv(cwd + "\\Result - Variogram.csv")
pd_Variogram.head()
# Out:
#    Distance        STD        CV       Range        Sill        Nugget
# 0        30  10.292980  0.256794   20.000000   71.762211  3.570080e+01
# 1       100  15.866641  0.478179   70.000000  267.887789  5.104219e-14
# 2       300  20.748732  0.428943  104.664412  449.836840  6.333086e+01
# 3       900  20.035755  0.502820  345.097181  438.814722  1.064037e+02
# 4      1200  19.909969  0.527853  327.228777  419.066655  8.059260e+01

# %%
pd_Roman = pd.read_csv(cwd + "\\Result - Roman.csv")
pd_Roman.head()
# Out:
#    Internal Distance  External Distance       Rcv       Rse       Rst  \
# 0                 30                100  0.862114  0.784802  0.990000
# 1                 30                300  0.670379  0.788821  0.694206
# 2                100                300 -0.102966  0.923035 -0.148640
# 3                300                900  0.172231  0.954540 -0.119004
# 4                300               1200  0.230590  0.954330 -0.075508
#
#         Rsv  RAW Score  ST Score
# 0  5.965000   0.579970  0.294941
# 1  7.947945   0.745846  0.256871
# 2  0.284701   4.855959  0.907602
# 3  1.906935   2.903070  0.592676
# 4  1.938959   2.168347  0.587308

# %%
pd_Roman.describe()
# Out:
#        Internal Distance  External Distance         Rcv         Rse  \
# count         438.000000         438.000000  438.000000  438.000000
# mean          158.082192         561.643836    1.264375    0.882509
# std           124.610047         409.485966    2.897092    0.081714
# min            30.000000         100.000000   -0.675273    0.755121
# 25%            30.000000         300.000000    0.086588    0.790276
# 50%           100.000000         300.000000    0.484816    0.910653
# 75%           300.000000         900.000000    1.194247    0.963527
# max           300.000000        1200.000000   24.093581    0.977386
#
#               Rst         Rsv   RAW Score    ST Score
# count  438.000000  438.000000  438.000000  438.000000
# mean     0.282524    4.312136    3.869146    0.496480
# std      0.577711    4.951875   13.903754    0.256922
# min     -0.813436   -0.403160    0.020752    0.063355
# 25%     -0.113691    0.885501    0.418680    0.296126
# ...

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of all the distance")
counts, edges, bars = plt.hist(pd_Variogram["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '241'),
#  Text(0, 0, '73'),
#  Text(0, 0, '30'),
#  Text(0, 0, '18'),
#  Text(0, 0, '5'),
#  Text(0, 0, '8'),
#  Text(0, 0, '11'),
#  Text(0, 0, '10'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
# ...

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 30m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==30]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '23'),
#  Text(0, 0, '10'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
# ...

# %%
pd_Variogram[pd_Variogram['Distance']==30]["Sill"].describe()
# Out:
# count     84.000000
# mean      20.190740
# std       32.125771
# min        0.013728
# 25%        2.564329
# 50%        7.767943
# 75%       17.465661
# max      136.224373
# Name: Sill, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 300m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==300]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '34'),
#  Text(0, 0, '16'),
#  Text(0, 0, '8'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
# ...

# %%
pd_Variogram[pd_Variogram['Distance']==300].describe()
# Out:
#        Distance        STD         CV       Range         Sill        Nugget
# count      84.0  84.000000  84.000000   84.000000    84.000000  8.400000e+01
# mean      300.0  10.135445   0.267043  158.805191   185.202721  1.371034e+01
# std         0.0   8.265601   0.243133   56.668212   338.548808  2.073719e+01
# min       300.0   0.300380   0.045821   37.605226     0.090163  4.633943e-19
# 25%       300.0   4.636348   0.110925  115.289882    21.366660  1.259513e-12
# 50%       300.0   7.710397   0.196082  173.344744    61.057152  3.117484e+00
# 75%       300.0  11.924367   0.291443  210.000000   149.232408  2.036060e+01
# max       300.0  40.138760   1.398979  210.000000  2016.824986  9.687454e+01

# %%
plt.figure(figsize = (20,10))
plt.title("Sills of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '27'),
#  Text(0, 0, '17'),
#  Text(0, 0, '15'),
#  Text(0, 0, '6'),
#  Text(0, 0, '4'),
#  Text(0, 0, '6'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
# ...

# %%
pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["Sill"].describe()
# Out:
# count     102.000000
# mean      312.170223
# std       450.856180
# min         0.150287
# 25%        46.555332
# 50%       108.416888
# 75%       409.586875
# max      2445.577708
# Name: Sill, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin(["600m","900m"])]["Sill"], bins = 50)
plt.xlabel("Sill")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0')]

# %%
plt.figure(figsize = (20,10))
plt.title("CV of all the distance")
counts, edges, bars = plt.hist(pd_Variogram["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '16'),
#  Text(0, 0, '47'),
#  Text(0, 0, '45'),
#  Text(0, 0, '51'),
#  Text(0, 0, '34'),
#  Text(0, 0, '27'),
#  Text(0, 0, '33'),
#  Text(0, 0, '31'),
#  Text(0, 0, '39'),
#  Text(0, 0, '12'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '11'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '6'),
#  Text(0, 0, '10'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '4'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
# ...

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 30m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==30]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '4'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '5'),
#  Text(0, 0, '7'),
#  Text(0, 0, '7'),
#  Text(0, 0, '7'),
#  Text(0, 0, '4'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance']==30]["CV"].describe()
# Out:
# count    84.000000
# mean      0.105642
# std       0.080160
# min       0.008956
# 25%       0.049552
# 50%       0.081538
# 75%       0.138398
# max       0.413030
# Name: CV, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("CVs of 300m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance']==300]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '5'),
#  Text(0, 0, '11'),
#  Text(0, 0, '10'),
#  Text(0, 0, '8'),
#  Text(0, 0, '4'),
#  Text(0, 0, '6'),
#  Text(0, 0, '6'),
#  Text(0, 0, '9'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
# ...

# %%
pd_Variogram[pd_Variogram['Distance']==300]["CV"].describe()
# Out:
# count    84.000000
# mean      0.267043
# std       0.243133
# min       0.045821
# 25%       0.110925
# 50%       0.196082
# 75%       0.291443
# max       1.398979
# Name: CV, dtype: float64

# %%
plt.figure(figsize = (20,10))
plt.title("CV of 600m & 900m distance")
counts, edges, bars = plt.hist(pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["CV"], bins = 50)
plt.xlabel("CV")
plt.ylabel("Count")
plt.bar_label(bars)
# Out:
# [Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '5'),
#  Text(0, 0, '9'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '8'),
#  Text(0, 0, '7'),
#  Text(0, 0, '1'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '5'),
#  Text(0, 0, '0'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
pd_Variogram[pd_Variogram['Distance'].isin([600,900])]["CV"].describe()
# Out:
# count    102.000000
# mean       0.332977
# std        0.246341
# min        0.048321
# 25%        0.172656
# 50%        0.251472
# 75%        0.435631
# max        1.278019
# Name: CV, dtype: float64
